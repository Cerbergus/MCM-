# %%
import os
from osgeo import gdal
import matplotlib.pyplot as plt
import numpy as np

# %%
dem = gdal.Open(r"C:\Users\Loz20\Pictures\Screenshots\屏幕截图 2025-01-26 000109.png")

# %%
Hillshade = gdal.DEMProcessing("Hillshade2 which lead to wear.tif", dem, "hillshade", computeEdges=True)

# %%
hillshade = gdal.Open(r"hillshade.tif")

# %%
hillshade = hillshade.GetRasterBand(1).ReadAsArray()

# %%
plt.figure(figsize=(15,10))
plt.imshow(hillshade,cmap="terrain")
plt.show()
